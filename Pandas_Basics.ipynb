# %% [markdown]
# <a href="https://colab.research.google.com/github/Prathyusha-Pasupuleti/mini_project1/blob/main/Pandas_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import random
age = []
height = []
weight = []
speed = []
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))

idata = {'Age':age,'Height':height,'Weight':weight,'Speed':speed}

# %%
idata
# Out:
# {'Age': [77,
#   47,
#   23,
#   63,
#   79,
#   62,
#   44,
#   96,
#   19,
#   74,
#   22,
#   51,
#   55,
#   72,
#   5,
#   63,
#   14,
#   80,
#   72,
#   18,
#   61,
#   53,
#   23,
#   53,
#   59,
#   20,
#   3,
#   41,
#   65,
#   4,
#   31,
#   95,
#   25,
#   34,
#   74,
#   53,
#   31,
#   14,
#   91,
#   48,
#   6,
#   97,
#   47,
#   3,
#   6,
#   71,
#   27,
#   88,
#   70,
#   79,
#   52,
#   55,
#   72,
#   88,
#   89,
#   65,
#   16,
#   72,
#   16,
#   64,
#   57,
#   18,
#   37,
#   68,
#   54,
#   56,
#   69,
#   85,
#   28,
#   73,
#   39,
#   82,
#   97,
#   13,
#   73,
#   22,
#   66,
#   23,
#   21,
#   71,
#   94,
#   71,
#   15,
#   89,
#   41,
#   11,
#   100,
#   19,
#   83,
#   97,
#   88,
#   20,
#   76,
#   15,
#   53,
#   16,
#   79,
#   48,
#   88,
#   33],
#  'Height': [56,
#   78,
#   46,
#   21,
#   0,
#   87,
#   85,
#   17,
#   63,
#   94,
#   100,
#   13,
#   36,
#   4,
#   84,
#   81,
#   41,
#   48,
#   97,
#   47,
#   48,
#   49,
#   59,
#   57,
#   20,
#   71,
#   52,
#   94,
#   57,
#   0,
#   23,
#   29,
#   86,
#   45,
#   37,
#   59,
#   58,
#   5,
#   95,
#   27,
#   19,
#   100,
#   49,
#   7,
#   2,
#   52,
#   92,
#   5,
#   63,
#   92,
#   6,
#   54,
#   5,
#   81,
#   49,
#   44,
#   70,
#   58,
#   4,
#   92,
#   37,
#   13,
#   35,
#   75,
#   84,
#   1,
#   81,
#   35,
#   86,
#   43,
#   23,
#   35,
#   29,
#   65,
#   64,
#   20,
#   61,
#   30,
#   48,
#   56,
#   10,
#   84,
#   46,
#   89,
#   93,
#   81,
#   100,
#   95,
#   92,
#   25,
#   53,
#   74,
#   97,
#   28,
#   13,
#   39,
#   81,
#   88,
#   100,
#   43],
#  'Weight': [46,
#   5,
#   44,
#   87,
#   10,
#   85,
#   92,
#   44,
#   94,
#   77,
#   26,
#   98,
#   77,
#   73,
#   32,
#   47,
#   45,
#   30,
#   28,
#   67,
#   55,
#   31,
#   53,
#   24,
#   94,
#   89,
#   29,
#   60,
#   56,
#   36,
#   78,
#   74,
#   57,
#   96,
#   14,
#   3,
#   28,
#   24,
#   15,
#   32,
#   82,
#   41,
#   16,
#   17,
#   39,
#   21,
#   56,
#   40,
#   89,
#   80,
#   76,
#   22,
#   41,
#   47,
#   49,
#   23,
#   15,
#   50,
#   95,
#   77,
#   20,
#   77,
#   18,
#   52,
#   42,
#   52,
#   87,
#   49,
#   5,
#   44,
#   60,
#   22,
#   50,
#   97,
#   53,
#   27,
#   27,
#   35,
#   61,
#   63,
#   9,
#   20,
#   73,
#   24,
#   99,
#   23,
#   52,
#   11,
#   8,
#   49,
#   11,
#   97,
#   38,
#   20,
#   28,
#   86,
#   93,
#   23,
#   81,
#   34],
#  'Speed': [93,
#   10,
#   99,
#   21,
#   96,
#   49,
#   50,
#   92,
#   22,
#   14,
#   9,
#   45,
#   43,
#   4,
#   31,
#   87,
#   9,
#   27,
#   23,
#   37,
#   93,
#   83,
#   56,
#   39,
#   85,
#   19,
#   92,
#   26,
#   20,
#   82,
#   16,
#   89,
#   72,
#   81,
#   73,
#   24,
#   51,
#   52,
#   86,
#   99,
#   75,
#   69,
#   10,
#   95,
#   38,
#   31,
#   45,
#   2,
#   91,
#   50,
#   23,
#   17,
#   50,
#   10,
#   86,
#   30,
#   82,
#   68,
#   99,
#   100,
#   19,
#   77,
#   61,
#   94,
#   60,
#   66,
#   12,
#   90,
#   66,
#   82,
#   28,
#   67,
#   68,
#   5,
#   79,
#   52,
#   30,
#   82,
#   17,
#   85,
#   7,
#   30,
#   79,
#   45,
#   50,
#   68,
#   59,
#   66,
#   87,
#   0,
#   60,
#   91,
#   91,
#   26,
#   79,
#   33,
#   22,
#   41,
#   90,
#   85]}

# %%
df1 = pd.DataFrame(idata)

# %%
df1
# Out:
#     Age  Height  Weight  Speed
# 0    77      56      46     93
# 1    47      78       5     10
# 2    23      46      44     99
# 3    63      21      87     21
# 4    79       0      10     96
# ..  ...     ...     ...    ...
# 95   16      39      86     33
# 96   79      81      93     22
# 97   48      88      23     41
# 98   88     100      81     90
# 99   33      43      34     85
#
# [100 rows x 4 columns]

# %%
df1.describe()
# Out:
#               Age      Height      Weight       Speed
# count  100.000000  100.000000  100.000000  100.000000
# mean    51.850000   52.650000   48.510000   54.190000
# std     28.333289   30.378879   27.658997   30.368676
# min      3.000000    0.000000    3.000000    0.000000
# 25%     23.000000   28.750000   24.000000   26.000000
# 50%     54.500000   52.000000   45.500000   54.000000
# 75%     73.250000   81.000000   74.500000   82.250000
# max    100.000000  100.000000   99.000000  100.000000

# %%
df1[['Age','Height']]
# Out:
#     Age  Height
# 0    77      56
# 1    47      78
# 2    23      46
# 3    63      21
# 4    79       0
# ..  ...     ...
# 95   16      39
# 96   79      81
# 97   48      88
# 98   88     100
# 99   33      43
#
# [100 rows x 2 columns]

# %%
df1.loc[[0,3],['Age','Height']]
# Out:
#    Age  Height
# 0   77      56
# 3   63      21

# %%
df1[0::2]
# Out:
#     Age  Height  Weight  Speed
# 0    77      56      46     93
# 2    23      46      44     99
# 4    79       0      10     96
# 6    44      85      92     50
# 8    19      63      94     22
# 10   22     100      26      9
# 12   55      36      77     43
# 14    5      84      32     31
# 16   14      41      45      9
# 18   72      97      28     23
# 20   61      48      55     93
# 22   23      59      53     56
# 24   59      20      94     85
# 26    3      52      29     92
# 28   65      57      56     20
# 30   31      23      78     16
# 32   25      86      57     72
# 34   74      37      14     73
# 36   31      58      28     51
# 38   91      95      15     86
# 40    6      19      82     75
# 42   47      49      16     10
# 44    6       2      39     38
# 46   27      92      56     45
# 48   70      63      89     91
# 50   52       6      76     23
# 52   72       5      41     50
# 54   89      49      49     86
# 56   16      70      15     82
# 58   16       4      95     99
# 60   57      37      20     19
# 62   37      35      18     61
# 64   54      84      42     60
# 66   69      81      87     12
# 68   28      86       5     66
# 70   39      23      60     28
# 72   97      29      50     68
# 74   73      64      53     79
# 76   66      61      27     30
# 78   21      48      61     17
# 80   94      10       9      7
# 82   15      46      73     79
# 84   41      93      99     50
# 86  100     100      52     59
# 88   83      92       8     87
# 90   88      53      11     60
# 92   76      97      38     91
# 94   53      13      28     79
# 96   79      81      93     22
# 98   88     100      81     90

# %%
df1[0::2]. describe()
# Out:
#               Age      Height     Weight      Speed
# count   50.000000   50.000000  50.000000  50.000000
# mean    50.640000   54.700000  48.920000  55.640000
# std     28.667524   30.658255  28.234326  29.963079
# min      3.000000    0.000000   5.000000   7.000000
# 25%     23.500000   35.250000  27.250000  24.250000
# 50%     53.500000   54.500000  47.500000  59.500000
# 75%     73.750000   84.000000  75.250000  84.250000
# max    100.000000  100.000000  99.000000  99.000000

# %%
df1.sort_index(ascending = True)
# Out:
#     Age  Height  Weight  Speed
# 0    77      56      46     93
# 1    47      78       5     10
# 2    23      46      44     99
# 3    63      21      87     21
# 4    79       0      10     96
# ..  ...     ...     ...    ...
# 95   16      39      86     33
# 96   79      81      93     22
# 97   48      88      23     41
# 98   88     100      81     90
# 99   33      43      34     85
#
# [100 rows x 4 columns]

# %%
 filter1 = df1['Weight'] > 50

# %%
df1[filter1]
# Out:
#     Age  Height  Weight  Speed
# 3    63      21      87     21
# 5    62      87      85     49
# 6    44      85      92     50
# 8    19      63      94     22
# 9    74      94      77     14
# 11   51      13      98     45
# 12   55      36      77     43
# 13   72       4      73      4
# 19   18      47      67     37
# 20   61      48      55     93
# 22   23      59      53     56
# 24   59      20      94     85
# 25   20      71      89     19
# 27   41      94      60     26
# 28   65      57      56     20
# 30   31      23      78     16
# 31   95      29      74     89
# 32   25      86      57     72
# 33   34      45      96     81
# 40    6      19      82     75
# 46   27      92      56     45
# 48   70      63      89     91
# 49   79      92      80     50
# 50   52       6      76     23
# 58   16       4      95     99
# 59   64      92      77    100
# 61   18      13      77     77
# 63   68      75      52     94
# 65   56       1      52     66
# 66   69      81      87     12
# 70   39      23      60     28
# 73   13      65      97      5
# 74   73      64      53     79
# 78   21      48      61     17
# 79   71      56      63     85
# 82   15      46      73     79
# 84   41      93      99     50
# 86  100     100      52     59
# 91   20      74      97     91
# 95   16      39      86     33
# 96   79      81      93     22
# 98   88     100      81     90

# %%
df1.loc[filter1]
# Out:
#     Age  Height  Weight  Speed
# 3    63      21      87     21
# 5    62      87      85     49
# 6    44      85      92     50
# 8    19      63      94     22
# 9    74      94      77     14
# 11   51      13      98     45
# 12   55      36      77     43
# 13   72       4      73      4
# 19   18      47      67     37
# 20   61      48      55     93
# 22   23      59      53     56
# 24   59      20      94     85
# 25   20      71      89     19
# 27   41      94      60     26
# 28   65      57      56     20
# 30   31      23      78     16
# 31   95      29      74     89
# 32   25      86      57     72
# 33   34      45      96     81
# 40    6      19      82     75
# 46   27      92      56     45
# 48   70      63      89     91
# 49   79      92      80     50
# 50   52       6      76     23
# 58   16       4      95     99
# 59   64      92      77    100
# 61   18      13      77     77
# 63   68      75      52     94
# 65   56       1      52     66
# 66   69      81      87     12
# 70   39      23      60     28
# 73   13      65      97      5
# 74   73      64      53     79
# 78   21      48      61     17
# 79   71      56      63     85
# 82   15      46      73     79
# 84   41      93      99     50
# 86  100     100      52     59
# 91   20      74      97     91
# 95   16      39      86     33
# 96   79      81      93     22
# 98   88     100      81     90

# %%
filter2 =df1['Age'] > 50

# %%
df1[filter1 &filter2]
# Out:
#     Age  Height  Weight  Speed
# 3    63      21      87     21
# 5    62      87      85     49
# 9    74      94      77     14
# 11   51      13      98     45
# 12   55      36      77     43
# 13   72       4      73      4
# 20   61      48      55     93
# 24   59      20      94     85
# 28   65      57      56     20
# 31   95      29      74     89
# 48   70      63      89     91
# 49   79      92      80     50
# 50   52       6      76     23
# 59   64      92      77    100
# 63   68      75      52     94
# 65   56       1      52     66
# 66   69      81      87     12
# 74   73      64      53     79
# 79   71      56      63     85
# 86  100     100      52     59
# 96   79      81      93     22
# 98   88     100      81     90
