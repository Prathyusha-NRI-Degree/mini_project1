# %%
def quiz():
    # List of questions, options, and correct answers
    questions = [
        {
            "question": "How many days are there in a Day?",
            "options": ["A. 5 days", "B. 7 days", "C. 8 days", "D. 6 days"],
            "answer": "B"
        },
        {
            "question": "How many hours are there in a Day?",
            "options": ["A. 24 hrs", "B. 20 hrs", "C. 27 hrs", "D. 18 hrs"],
            "answer": "A"
        },
        {
            "question": "How many letters are there in a English Alphabet?",
            "options": ["A. 22 letters", "B. 27 letters", "C. 26 letters", "D. 25 letters"],
            "answer": "C"
        },
        {
            "question": "Which element has the chemical symbol O?",
            "options": ["A. Oxygen", "B. Gold", "C. Hydrogen", "D. Nitrogen"],
            "answer": "A"
        },
        {
            "question": "What is the smallest prime number?",
            "options": ["A. 1", "B. 2", "C. 3", "D. 5"],
            "answer": "B"
        },
        {
            "question": "What is the speed of light?",
            "options": ["A. 300,000 km/s", "B. 150,000 km/s", "C. 400,000 km/s", "D. 250,000 km/s"],
            "answer": "A"
        },
        {
            "question": "What is the square root of 16?",
            "options": ["A. 2", "B. 3", "C. 4", "D. 8"],
            "answer": "C"
        },
        {
            "question": "Which is the longest river in the world?",
            "options": ["A. Amazon", "B. Nile", "C. Yangtze", "D. Ganges"],
            "answer": "B"
        },
        {
            "question": "What is the chemical formula of water?",
            "options": ["A. CO2", "B. H2O", "C. O2", "D. CH4"],
            "answer": "B"
        },
        {
            "question": "Which country is known as the Land of the Rising Sun?",
            "options": ["A. China", "B. Japan", "C. South Korea", "D. Thailand"],
            "answer": "B"
        }
    ]

    total_score = 0  

    
    for i, question in enumerate(questions, start=1):
        print(f"Question {i}: {question['question']}")
        for option in question['options']:
            print(option)

        
        user_answer = input("Enter your answer (A/B/C/D): ").upper()

        
        match user_answer:
            case answer if answer == question['answer']:
                print("Correct Answer")
                total_score += 10  # Add 10 marks for a correct answer
            case _:
                print(f"Wrong! The correct answer is {question['answer']}.")

        print()  

    # Final score
    print(f"Your total score is {total_score} out of {len(questions) * 10}.")

# Run the quiz game
quiz()
# Out:
# Question 1: How many days are there in a Day?
# A. 5 days
# B. 7 days
# C. 8 days
# D. 6 days
# Wrong! The correct answer is B.
#
# Question 2: How many hours are there in a Day?
# A. 24 hrs
# B. 20 hrs
# C. 27 hrs
# D. 18 hrs
# Correct Answer
#
# Question 3: How many letters are there in a English Alphabet?
# A. 22 letters
# B. 27 letters
# C. 26 letters
# D. 25 letters
# Wrong! The correct answer is C.
#
# Question 4: Which element has the chemical symbol O?
# A. Oxygen
# B. Gold
# C. Hydrogen
# D. Nitrogen
# Wrong! The correct answer is A.
#
# Question 5: What is the smallest prime number?
# A. 1
# B. 2
# C. 3
# D. 5
# Wrong! The correct answer is B.
#
# Question 6: What is the speed of light?
# A. 300,000 km/s
# B. 150,000 km/s
# C. 400,000 km/s
# D. 250,000 km/s
# Correct Answer
#
# Question 7: What is the square root of 16?
# A. 2
# B. 3
# C. 4
# D. 8
# Wrong! The correct answer is C.
#
# Question 8: Which is the longest river in the world?
# A. Amazon
# B. Nile
# C. Yangtze
# ...
